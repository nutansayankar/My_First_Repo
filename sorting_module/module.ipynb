# %%
import sort
sort.bubble_sort([5,6,4,7,2,1])
# Out:
# [1, 2, 4, 5, 6, 7]

# %%
import sort

# %%
sort.merge_sort([4,5,3,2,6,7,1])
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
sort.insertion_sort([3,4,5,2,5,6,1])
# Out:
# [1, 2, 3, 4, 5, 5, 6]
